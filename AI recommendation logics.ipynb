# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
Data = {
    "Courses": [
        "python Basics",
        "Machine Learning",
        "Web Development",
        "cyber Security",
        "Cloud Computing",
        "Big Data"
    ],
      "Tags":[
          "Python programming libraries",
          "Python ai machine learning",
          "html css javascript node react",
          "cyber hacks security cryptography",
          "aws cloud develops",
          "sparks big data hadoop data security"
      ]
}
df=pd.DataFrame(Data)
print(df)
# Out:
#             Courses                                  Tags
# 0     python Basics          Python programming libraries
# 1  Machine Learning            Python ai machine learning
# 2   Web Development        html css javascript node react
# 3    cyber Security     cyber hacks security cryptography
# 4   Cloud Computing                    aws cloud develops
# 5          Big Data  sparks big data hadoop data security

# %%
df.to_csv("courses.csv",index=False)

# %%
df=pd.read_csv("courses.csv")
print(df)
# Out:
#             Courses                                  Tags
# 0     python Basics          Python programming libraries
# 1  Machine Learning            Python ai machine learning
# 2   Web Development        html css javascript node react
# 3    cyber Security     cyber hacks security cryptography
# 4   Cloud Computing                    aws cloud develops
# 5          Big Data  sparks big data hadoop data security

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.9.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached scikit_learn-1.9.0-cp314-cp314-win_amd64.whl (8.3 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.22.1-py3-none-any.whl (454 kB)
# ...
#
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
#    ---------------------------------------- 0/3 [narwhals]
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df=pd.read_csv("courses.csv")
df.head()
# Out:
#             Courses                               Tags
# 0     python Basics       Python programming libraries
# 1  Machine Learning         Python ai machine learning
# 2   Web Development     html css javascript node react
# 3    cyber Security  cyber hacks security cryptography
# 4   Cloud Computing                 aws cloud develops

# %%
tfidf=TfidfVectorizer()
vector = tfidf.fit_transform(df["Tags"])

# %%
print(vector.shape)
# Out:
# (6, 22)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
user_choice= input("enter your interest field")
# Out:
# enter your interest field aws

# %%
user_vector=tfidf.transform([user_choice])

# %%
similar_courses = cosine_similarity(user_vector,vector)
print(similar_courses)
# Out:
# [[0.         0.         0.         0.         0.57735027 0.        ]]
